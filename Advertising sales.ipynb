# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# There are 200 rows and 5 columns

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# It gives the statistical values

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %% [markdown]
# Here all the columns are in float data type except unnamed:0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %% [markdown]
# No null values are present here

# %%
df['sales'].unique()
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. ,  5.6,
#        15.5, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,  9.5, 12.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 14.9, 23.2, 14.8,
#        11.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1, 24.2,
#        15.7, 14. , 13.4, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 12.3, 13.6, 21.7, 15.2, 16. , 16.7, 11.2,  7.3, 19.4,
#        22.2, 11.5, 16.9, 11.7, 17.2, 19.2, 19.8, 21.8, 14.1, 12.6, 12.2,
#         9.4,  6.6,  7. , 11.6, 19.7, 24.7,  1.6, 12.7,  5.7, 19.6, 10.8,
#        20.8, 10.9, 20.1, 10.3, 16.1, 15.6,  3.2, 15.3, 14.4, 13.3,  8. ,
#         8.4, 14.5,  7.6, 27. , 26.2, 17.6, 17.3,  6.7,  9.9,  5.9, 25.5])

# %%
print(df['sales'].value_counts())
# Out:
# 9.7     5
# 15.9    4
# 11.7    4
# 12.9    4
# 20.7    3
#        ..
# 25.5    1
# 15.6    1
# 17.6    1
# 3.2     1
# 20.8    1
# Name: sales, Length: 121, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate analysis

# %%
sn.countplot(df['sales']);

# %% [markdown]
# It gives the sales aganist the counts

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# These are the column names

# %%
sn.distplot(df["sales"])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# Its normaly distributed

# %%
sn.distplot(df["TV"])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %% [markdown]
# Its not normally distributed

# %%
sn.distplot(df["radio"])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# Its not normaly distributed

# %%
sn.distplot(df["newspaper"])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# There is right skewness present here

# %%
df.plot(kind="box",subplots=True,layout=(2,7))# 2 row and 7 columns
# Out:
# Unnamed: 0       AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# TV            AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# radio         AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# newspaper     AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# sales         AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# dtype: object

# %% [markdown]
# There are outliers present in the news papers

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Tv and Sales")
sn.scatterplot(df['TV'],df['sales'],hue=df["sales"])
# Out:
# <AxesSubplot:title={'center':'comparison between Tv and Sales'}, xlabel='TV', ylabel='sales'>

# %% [markdown]
# It gives the number of Tv in sales

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Radio and Sales")
sn.scatterplot(df['radio'],df['sales'],hue=df["sales"])
# Out:
# <AxesSubplot:title={'center':'comparison between Radio and Sales'}, xlabel='radio', ylabel='sales'>

# %% [markdown]
# It gives the number of Tv in sales

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between newspaper and Sales")
sn.scatterplot(df['newspaper'],df['sales'],hue=df["sales"])
# Out:
# <AxesSubplot:title={'center':'comparison between newspaper and Sales'}, xlabel='newspaper', ylabel='sales'>

# %% [markdown]
# It gives the number of newspaper in sales

# %%
sn.pairplot(df,hue='sales')

# %% [markdown]
# It gives the the scatterplot of each column against each independent variables

# %%
df1=df.drop(['Unnamed: 0'], axis = 1)
df1
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# dropped the column 'Unnamed: 0'

# %%
cor=df1.corr()
cor
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# It gives the correlation between the variables

# %%
plt.figure(figsize=[20,10])
sn.heatmap(cor,annot=True,linewidths=6,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here no independent variables are highly negatively correlated with target

# %% [markdown]
# # Outlier removing

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1))
new_df=df1[(z<3).all(axis=1)]

# %%
new_df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
new_df.shape
# Out:
# (198, 4)

# %%
df1.shape
# Out:
# (200, 4)

# %% [markdown]
# removed 2 rows because of outliers

# %% [markdown]
# # skewness

# %%
new_df.skew()
# Out:
# TV          -0.082332
# radio        0.114842
# newspaper    0.650112
# sales        0.407130
# dtype: float64

# %% [markdown]
# There is a skewness in newspaper . But it very low

# %%
#from scipy.stats import boxcox
#new_df['newspaper']=boxcox(new_df['newspaper'],0)

# %%
#new_df.skew()

# %% [markdown]
# # sepearation columns into features and target

# %%
x=new_df.iloc[:,0:-1]
x.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8   4.237001
# 1   44.5   39.3   3.808882
# 2   17.2   45.9   4.238445
# 3  151.5   41.3   4.069027
# 4  180.8   10.8   4.067316

# %%
y=new_df.iloc[:,-1]
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Find the best random states use here

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=12)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# linear regression fitting into x-train and y-train

# %%
lr.coef_
# Out:
# array([0.04531775, 0.18853237, 0.02376943])

# %% [markdown]
# Got the linear regression coefficient

# %%
lr.intercept_
# Out:
# 2.9276996809148486

# %% [markdown]
# Got the linear regression constant

# %%
pred_test=lr.predict(x_test)

# %%
print("prexicted value is",pred_test)
print("actual value is",y_test)
# Out:
# prexicted value is [18.26164072 17.21514936 11.97671554 16.38003822 15.69734444  6.61635438
#  17.0179991  16.77309226 12.12838695 21.6262472  18.70612425  8.64477923
#  19.29491097 23.24159226  8.1955989   9.88944786 13.92639296  4.58969593
#  17.00741257 10.49105897 19.52008868 14.80230507 20.68370479  7.44978771
#  17.85410279 24.16956492 12.5082147   7.69622823 13.02393255 15.23619914
#  10.25008066 21.46930967 19.59613589 11.63598726 15.47741788 12.44419687
#  12.64382141 16.29564333 20.79137546 16.33835776]
# actual value is 153    19.0
# 11     17.4
# 134    10.8
# 95     16.9
# 87     16.0
# 22      5.6
# 64     18.0
# 62     15.7
# 7      13.2
# 30     21.4
# 33     17.4
# 56      5.5
# 133    19.6
# 17     24.4
# 24      9.7
# 149    10.1
# 181    12.2
# 91      7.3
# 99     17.2
# 94     11.5
# 124    19.7
# 110    13.4
# 52     22.6
# 170     8.4
# 169    15.0
# 183    26.2
# 190    10.8
# 32      9.6
# 115    12.6
# 146    13.2
# 82     11.3
# 42     20.7
# 139    20.7
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("mean absoute value",mean_absolute_error(y_test,pred_test))
print("mean squared error",mean_squared_error(y_test,pred_test))
print ("Root mean squared error",np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# mean absoute value 1.262081540582829
# mean squared error 2.6392873222648587
# Root mean squared error 1.624588354711697

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9007450896068272

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,1,10],
            'random_state':list(range(0,10)),
            'fit_intercept':[True,False],
            'selection':['cyclic', 'random']}
ls = Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'fit_intercept': True, 'random_state': 9, 'selection': 'random'}

# %% [markdown]
# These are the best parameters

# %%
ls = Lasso(alpha=1,random_state=9,fit_intercept=True,selection ='random')
ls.fit(x_train,y_train)
ls.score(x_train,y_train)

pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.9007111371912182

# %% [markdown]
# # cross validation

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.887642773105356

# %% [markdown]
# # ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],
            'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %% [markdown]
# These are the best parameters

# %%
rf= RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)

pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print("R2_score",rfs*100)

rfs_score=cross_val_score(rf,x,y,cv=5)
rfc=rfs_score.mean()
print("Cross_val_score",rfc*100)
# Out:
# R2_score 98.52650586664662
# Cross_val_score 97.7727276011425

# %% [markdown]
# Here Getting the model accuracy as 98% and 97% .

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='sales.pkl'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# saved the model

# %% [markdown]
# # conclusion

# %%
loaded_model=pickle.load(open('sales.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9852650586664662

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                0       1       2      3       4      5       6       7   \
# Predicted  18.712  16.999  10.586  17.36  15.906  6.181  17.157  15.463
# Original   18.712  16.999  10.586  17.36  15.906  6.181  17.157  15.463
#
#                8       9   ...      30      31      32      33      34  \
# Predicted  12.737  20.186  ...  11.445  19.953  21.338  12.293  14.358
# Original   12.737  20.186  ...  11.445  19.953  21.338  12.293  14.358
#
#                35     36      37      38      39
# Predicted  11.219  7.148  15.597  22.224  16.342
# Original   11.219  7.148  15.597  22.224  16.342
#
# [2 rows x 40 columns]

# %% [markdown]
# Predicted values and original values are same
